# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("run_y24-m04-d04_h18-m44_hlTIg.csv")
df
# Out:
#      index                       run_name        vx        vy     vx_sp  \
# 0        0  run_y24-m04-d04_h18-m44_hlTIg  0.001000 -0.078249 -0.012725
# 1        1  run_y24-m04-d04_h18-m44_hlTIg -0.004666  0.044594  0.305072
# 2        2  run_y24-m04-d04_h18-m44_hlTIg -0.000301  0.004323  0.382799
# 3        3  run_y24-m04-d04_h18-m44_hlTIg -0.000241  0.003449  0.417355
# 4        4  run_y24-m04-d04_h18-m44_hlTIg -0.000193  0.002760  0.441957
# ..     ...                            ...       ...       ...       ...
# 489    489  run_y24-m04-d04_h18-m44_hlTIg  0.733630 -0.166464  0.961481
# 490    490  run_y24-m04-d04_h18-m44_hlTIg  0.731604 -0.173072  0.959157
# 491    491  run_y24-m04-d04_h18-m44_hlTIg  0.729594 -0.179419  0.956825
# 492    492  run_y24-m04-d04_h18-m44_hlTIg  0.727598 -0.185596  0.954469
# 493    493  run_y24-m04-d04_h18-m44_hlTIg  0.725626 -0.191627  0.952081
#
#         vy_sp  yaw_rate                            camera_img
# ...

# %%
fig, axs = plt.subplots(2)
fig.suptitle("aaa")
axs[0].plot(df["vx"], label="Vx measured")
axs[0].plot(df["vx_sp"]*0.75, label="Vx setpoint")
axs[0].set_title("Vx")
axs[0].legend()
axs[1].plot(df["vy"], label="Vy measured")
axs[1].plot(df["vy_sp"]*0.75, label="Vy setpoint")
axs[1].set_title("Vy")
# Out:
# Text(0.5, 1.0, 'Vy')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time
from IPython.display import clear_output

# Call clear_output() to clear the output of the current cell

def show_image(image_path):
    # Read the image
    
    img = mpimg.imread(image_path)
    
    # Display the image
    plt.imshow(img)
    plt.axis('off')  # Hide axis
    plt.show()

for i in range(500,1000):
    image_path = f"/home/florentin/Documents/webots_simulations/bitcraze_rl/controllers/gate_following_controller/data/images/run_y24-m04-d07_h15-m34_mkbru_img{i}.png"  # Change this to your image file path
    print(i)
    show_image(image_path)
    time.sleep(1/32)
    clear_output(wait=True)
# Out:
# 559
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 22
#      20 print(i)
#      21 show_image(image_path)
# ---> 22 time.sleep(1/32)
#      23 clear_output(wait=True)
#
# KeyboardInterrupt:
